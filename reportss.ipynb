# %% [markdown]
# Task 1: Import packages and Load data

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

path="C:/HocTap/Nam4/HocKy1/CongNgheDuLieu/Sales-Reporting-main/data/"
df = pd.read_csv(path + "sales2019_3.csv")
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       162009                      iPhone                1        700
# 1       162009    Lightning Charging Cable                1      14.95
# 2       162009            Wired Headphones                2      11.99
# 3       162010  Bose SoundSport Headphones                1      99.99
# 4       162011      34in Ultrawide Monitor                1     379.99
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# ...

# %% [markdown]
# Task 2: Clean and Preprocess data

# %% [markdown]
# Task 2.1: Merge 12-month data

# %%
#In ra các file có trong path
#Lấy đường dẫn của các file
#In ra từng file 1 và gộp lại qua concat()

# filepaths = []
frames = []
all_length = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + file #Tạo path cho từng tập tin
        # filepaths.append(filepath) #List đường dẫn

        #Tạo dataframe cho từng tập tin dựa qua path
        df1 = pd.read_csv(filepath)
        frames.append(df1) #Thêm dataframe vào trong danh sách frame
        result = pd.concat(frames) #Truyền danh sách đó vào trong phương thức concat()
        length_1month = len(df1.index)
        all_length.append(length_1month)

# df1 = pd.read_csv(filepaths[3])
df = result
df.to_csv('annualSale2019.csv', index=False)
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215
# ...

# %%
print(sum(all_length))
# Out:
# 186850

# %% [markdown]
# Task 2.2: Add 'Month' column

# %%
df['Month'] = df['Order Date'].str[0:2]
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
print(set(df['Month']))
# Out:
# {'02', '04', '06', '08', nan, '01', '11', '03', '05', '12', '10', '09', '07', 'Or'}

# %% [markdown]
# Task 2.3: Get rid of 'NaN' and 'Or' value

# %%
df = df.dropna(how='all')
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone               1.0  700.000000
# 1   141235  Lightning Charging Cable               1.0   14.950000
# 2   141236          Wired Headphones               2.0   11.990000
# 3   141237          27in FHD Monitor               1.0  149.990005
# 4   141238          Wired Headphones               1.0   11.990000
#
#         Sales      Order Date                       Purchase Address Month
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
df = df[df['Month'] != 'Or']
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone               1.0  700.000000
# 1       141235  Lightning Charging Cable               1.0   14.950000
# 2       141236          Wired Headphones               2.0   11.990000
# 3       141237          27in FHD Monitor               1.0  149.990005
# 4       141238          Wired Headphones               1.0   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)               3.0    2.990000
# 11682   259354                    iPhone               1.0  700.000000
# 11683   259355                    iPhone               1.0  700.000000
# 11684   259356    34in Ultrawide Monitor               1.0  379.989990
# 11685   259357      USB-C Charging Cable               1.0   11.950000
#
#             Sales      Order Date                         Purchase Address  \
# ...

# %% [markdown]
# Task 3: Reporting

# %% [markdown]
# Task 3.1: What was the best month for sales? How much was earned that month?

# %%
print(df['Quantity Ordered'].dtype)
print(df['Price Each'].dtype)
# Out:
# int8
# float32

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], downcast='integer')
df['Price Each'] = pd.to_numeric(df['Price Each'], downcast='float')

# %%
df['Sale'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month  \
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01
#
#          Sale
# 0  700.000000
# 1   14.950000
# 2   23.980000
# 3  149.990005
# 4   11.990000

# %%
moving_column = df.pop('Sale')
df.insert(4, 'Sales', moving_column)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2644\28231878.py in ?()
#       1 moving_column = df.pop('Sale')
# ----> 2 df.insert(4, 'Sales', moving_column)
#       3 df
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Sales, already exists

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
df.groupby('Month').sum()['Sales']
# Out:
# Month
# 01    1.822257e+06
# 02    2.202022e+06
# 03    2.807100e+06
# 04    3.390670e+06
# 05    3.152607e+06
# 06    2.577802e+06
# 07    2.647776e+06
# 08    2.244468e+06
# 09    2.097560e+06
# 10    3.736727e+06
# 11    3.199603e+06
# 12    4.613443e+06
# Name: Sales, dtype: float64

# %%
sales_value = df.groupby('Month').sum()['Sales']
sales_value.max()
# Out:
# np.float64(4613443.316063166)

# %%
months = range(1,13)
plt.bar(x=months, height=sales_value)
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# Task 3.2: What city has the best sales?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
address_to_city = lambda address:address.split(',')[1]

# %%
df['City'] = df['Purchase Address'].apply(address_to_city)
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month  \
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01
#
#              City
# 0          Boston
# 1        Portland
# 2   San Francisco
# 3     Los Angeles
# ...

# %%
df.groupby('City').sum()['Sales']
# Out:
# City
# Atlanta          2.795499e+06
# Austin           1.819582e+06
# Boston           3.661642e+06
# Dallas           2.767975e+06
# Los Angeles      5.452571e+06
# New York City    4.664317e+06
# Portland         2.320491e+06
# San Francisco    8.262204e+06
# Seattle          2.747755e+06
# Name: Sales, dtype: float64

# %%
sales_value_city = df.groupby('City').sum()['Sales']
sales_value_city.max()
# Out:
# np.float64(8262203.869146585)

# %%
cities = [city for city, sale in sales_value_city.items()]
print(cities)
# Out:
# [' Atlanta', ' Austin', ' Boston', ' Dallas', ' Los Angeles', ' New York City', ' Portland', ' San Francisco', ' Seattle']

# %%
plt.bar(x=cities, height=sales_value_city)
plt.xticks(cities, rotation=90)
plt.xlabel('Cities')
plt.ylabel('Sales in USD')
plt.show()

# %%
print(cities)
print(sales_value_city)
# Out:
# [' Boston' ' Portland' ' San Francisco' ' Los Angeles' ' Austin'
#  ' Atlanta' ' Seattle' ' New York City' ' Dallas']
# City
# Atlanta          2.795499e+06
# Austin           1.819582e+06
# Boston           3.661642e+06
# Dallas           2.767975e+06
# Los Angeles      5.452571e+06
# New York City    4.664317e+06
# Portland         2.320491e+06
# San Francisco    8.262204e+06
# Seattle          2.747755e+06
# Name: Sales, dtype: float64

# %% [markdown]
# Task 3.3: What time should we display ads to maximize the likelihood of customer’s buying product?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month  \
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01
#
#              City
# 0          Boston
# 1        Portland
# 2   San Francisco
# 3     Los Angeles
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2644\3072535395.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
print(df['Order Date'].dtype)
# Out:
# datetime64[ns]

# %%
df['Hours'] = df['Order Date'].dt.hour
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales          Order Date                       Purchase Address  \
# 0  700.000000 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1   14.950000 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2   23.980000 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3  149.990005 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4   11.990000 2019-01-25 11:59:00          387 10th St, Austin, TX 73301
#
#   Month            City  Hours
# 0    01          Boston     21
# 1    01        Portland     14
# ...

# %%
sales_value_hours = df.groupby('Hours').count()['Sales']
hours = [hour for hour, sales in sales_value_hours.items()]
plt.plot(hours, sales_value_hours)
plt.grid()
plt.xticks(hours, rotation=90, size=8)
plt.xlabel('Hours')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# Task 3.4: What products are most often sold together? Trùng ID, giờ mua, địa điểm mua

# %%
df_dup = df[df['Order ID'].duplicated(keep=False)]
df_dup.head()
# Out:
#     Order ID                   Product  Quantity Ordered  Price Each   Sales  \
# 41    141275      USB-C Charging Cable                 1       11.95   11.95
# 42    141275          Wired Headphones                 1       11.99   11.99
# 57    141290  Apple Airpods Headphones                 1      150.00  150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84   11.52
# 133   141365           Vareebadd Phone                 1      400.00  400.00
#
#              Order Date                        Purchase Address Month  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01
# 42  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01
# 57  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01
# 58  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01
# 133 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001    01
#
#                City  Hours
# 41           Austin     16
# ...

# %%
# df_dup = df[df['Order ID'].duplicated(keep=False)]
groupProduct = lambda product: ', '.join(product)
df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
df_dup = df_dup[['Order ID', 'All Products']].drop_duplicates()
df_dup['All Products'].value_counts().head(10)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2644\1465987281.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
# All Products
# iPhone, Lightning Charging Cable                        882
# Google Phone, USB-C Charging Cable                      856
# iPhone, Wired Headphones                                361
# Vareebadd Phone, USB-C Charging Cable                   312
# Google Phone, Wired Headphones                          303
# iPhone, Apple Airpods Headphones                        286
# Google Phone, Bose SoundSport Headphones                161
# Vareebadd Phone, Wired Headphones                       104
# ...

# %% [markdown]
# Task 3.5: What product sold the most? Why do you think it sold the most?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales          Order Date                       Purchase Address  \
# 0  700.000000 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1   14.950000 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2   23.980000 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3  149.990005 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4   11.990000 2019-01-25 11:59:00          387 10th St, Austin, TX 73301
#
#   Month            City  Hours
# 0    01          Boston     21
# 1    01        Portland     14
# ...

# %%
print(df['Quantity Ordered'].dtype)
print(df['Price Each'].dtype)
# Out:
# int8
# float32

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], errors='coerce')
df['Price Each'] = pd.to_numeric(df['Price Each'], errors='coerce')

# %%
# Kiểm tra kết quả groupby
print(df.groupby('Product').sum()['Quantity Ordered'])
print(df.groupby('Product').mean()['Price Each'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 # Kiểm tra kết quả groupby
# ----> 2 print(df.groupby('Product').sum()['Quantity Ordered'])
#       3 print(df.groupby('Product').mean()['Price Each'])
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
# ...

# %%
all_products = df.groupby('Product').sum()['Quantity Ordered']
prices = df.groupby('Product').mean()['Price Each']
products_ls = [product for product, quant in all_products.items()]

x = products_ls
y1 = all_products
y2 = prices

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(x, y1, color='g')
ax2.plot(x, y2, 'b-')

ax1.set_xticklabels(products_ls, rotation=90, size=8)
ax1.set_xlabel('Products')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price Each', color='b')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 all_products = df.groupby('Product').sum()['Quantity Ordered']
#       2 prices = df.groupby('Product').mean()['Price Each']
#       3 products_ls = [product for product, quant in all_products.items()]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
# ...
